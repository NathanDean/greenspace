# %% [markdown]
# # Imports

# %%
import pickle
import numpy as np
import geopandas as gpd
import tensorflow as tf
from utils.db_utils import engine
from utils.nested_cv.ann import (
    evaluate_ann
)

# %% [markdown]
# # Set random seeds

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %% [markdown]
# # Prepare data

# %%
raw_df = gpd.read_postgis("SELECT * FROM split_engineered_dataset", engine, "geometry")

# %%
df = raw_df.copy()
df = df.drop(columns = ["ogc_fid"])

# %% [markdown]
# # Evaluate model

# %%
results = evaluate_ann(df, regularised=True)

# %% [markdown]
# # Save output

# %%
with open("outputs/model_results/regularised_ann_fe.pkl", "wb") as f:
    pickle.dump(results, f)
